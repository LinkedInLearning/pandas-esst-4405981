# %%
import pandas as pd

# %%
df = pd.read_csv("../data/members.csv")

# %%
df.tail(30)
# Out:
#       ID First Name  Last Name                         Email          Phone  \
# 270  370      Marie     Romero           mromero7i@fotki.com  (917)433-5318
# 271  371    Melissa    Wheeler          mwheeler7j@jimdo.com  (516)641-4662
# 272  372       Fred     Morris           fmorris7k@yandex.ru  (202)992-8383
# 273  373    Michael      Burke           mburke7l@spiegel.de  (765)699-6462
# 274  374       Sara   Phillips     sphillips7m@bloglovin.com  (804)171-1256
# 275  375     Angela  Hernandez         ahernandez7n@furl.net  (860)450-9884
# 276  376   Patricia    Carroll        pcarroll7o@jiathis.com  (661)496-7816
# 277  377      Emily       Ryan              eryan7p@dmoz.org  (754)154-3364
# 278  378       Joan      Stone             jstone7q@furl.net  (202)785-1176
# 279  379     Joshua     Rivera        jrivera7r@sakura.ne.jp  (202)351-0177
# 280  380     Amanda     Bowman  abowman7s@barnesandnoble.com  (816)919-3527
# ...

# %%
df.sort_values("Member Type")
# Out:
#       ID First Name  Last Name                     Email          Phone  \
# 0    100      Carol       Shaw            cshaw0@mlb.com  (206)804-8771
# 159  259      Debra      Jones        djones4f@weibo.com  (914)467-2219
# 160  260      Norma     Lawson      nlawson4g@netlog.com  (215)213-8307
# 161  261  Elizabeth  Robertson  erobertson4h@state.tx.us  (210)219-3930
# 162  262       Paul        Ray          pray4i@sogou.com  (202)341-0847
# ..   ...        ...        ...                       ...            ...
# 56   156     Andrew    Nichols       anichols1k@time.com  (405)462-7126
# 57   157      Sarah     Cooper         scooper1l@nba.com  (812)331-9986
# 278  378       Joan      Stone         jstone7q@furl.net  (202)785-1176
# 51   151       Earl   Richards     erichards1f@google.nl  (281)133-3455
# 219  319       Tina    Jackson       tjackson63@narod.ru  (305)791-7531
#
#     Customer Type  Member Type
# 0      Individual            1
# 159    Individual            1
# ...

# %%
df.sort_values("Member Type", ascending=False)
# Out:
#       ID First Name  Last Name                         Email          Phone  \
# 57   157      Sarah     Cooper             scooper1l@nba.com  (812)331-9986
# 223  323      Peter       Hall                phall67@ca.gov  (405)690-9653
# 56   156     Andrew    Nichols           anichols1k@time.com  (405)462-7126
# 55   155      Sarah     Taylor           staylor1j@yandex.ru  (937)243-9631
# 54   154      Diane      Scott               dscott1i@ft.com  (616)994-9361
# ..   ...        ...        ...                           ...            ...
# 152  252    Mildred   Williams           mwilliams48@sun.com  (661)691-6057
# 153  253     Teresa       Reed        treed49@prnewswire.com  (619)152-4245
# 154  254    Anthony       King                aking4a@wp.com  (281)318-2460
# 155  255       Tina     Kelley           tkelley4b@slate.com  (214)711-7757
# 299  399      David  Robertson  drobertson8b@istockphoto.com  (404)982-4393
#
#     Customer Type  Member Type
# ...

# %%
df.sort_values(["Member Type","ID"])
# Out:
#       ID First Name Last Name                 Email          Phone  \
# 0    100      Carol      Shaw        cshaw0@mlb.com  (206)804-8771
# 1    101  Elizabeth      Carr     ecarr1@oracle.com  (512)187-2507
# 2    102     Ernest     Ramos   eramos2@plala.or.jp  (816)540-4257
# 3    103       Jane    Carter  jcarter3@harvard.edu  (214)839-0542
# 4    104     Martha    Cooper       mcooper4@go.com  (727)235-5696
# ..   ...        ...       ...                   ...            ...
# 221  321     Denise     Myers     dmyers65@ucoz.com  (202)646-6358
# 222  322     Brenda       Day    bday66@myspace.com  (814)920-1804
# 223  323      Peter      Hall        phall67@ca.gov  (405)690-9653
# 273  373    Michael     Burke   mburke7l@spiegel.de  (765)699-6462
# 278  378       Joan     Stone     jstone7q@furl.net  (202)785-1176
#
#     Customer Type  Member Type
# 0      Individual            1
# 1      Individual            1
# 2      Individual            1
# 3      Individual            1
# ...

# %%
df.sort_values(["Member Type","ID"], ascending=[False,True])
# Out:
#       ID First Name  Last Name                         Email          Phone  \
# 50   150       Sean      Myers              smyers1e@dot.gov  (214)923-5599
# 51   151       Earl   Richards         erichards1f@google.nl  (281)133-3455
# 52   152    Brandon     Murray         bmurray1g@state.tx.us  (843)611-5603
# 53   153    Matthew     Jacobs        mjacobs1h@linkedin.com  (336)125-0595
# 54   154      Diane      Scott               dscott1i@ft.com  (616)994-9361
# ..   ...        ...        ...                           ...            ...
# 295  395      Diana      Hicks        dhicks87@bloglovin.com  (513)289-6421
# 296  396     Thomas    Griffin        tgriffin88@smugmug.com  (801)631-7393
# 297  397   Jonathan     Turner             jturner89@fc2.com  (310)968-4752
# 298  398     Jeremy   Robinson           jrobinson8a@gnu.org  (616)146-1693
# 299  399      David  Robertson  drobertson8b@istockphoto.com  (404)982-4393
#
#     Customer Type  Member Type
# ...

# %%
df = pd.read_csv("../data/member_type.csv")

# %%
df
# Out:
#    Type No   Type Name  Price
# 0        1   Full Time     50
# 1        2    Day Time     25
# 2        3  Night Time     35
# 3        4     Weekday     40

# %%
df1 = df.sort_values("Price")

# %%
df1
# Out:
#    Type No   Type Name  Price
# 1        2    Day Time     25
# 2        3  Night Time     35
# 3        4     Weekday     40
# 0        1   Full Time     50

# %%
df
# Out:
#    Type No   Type Name  Price
# 0        1   Full Time     50
# 1        2    Day Time     25
# 2        3  Night Time     35
# 3        4     Weekday     40

# %%
df.sort_values("Price", inplace=True)

# %%
df
# Out:
#    Type No   Type Name  Price
# 1        2    Day Time     25
# 2        3  Night Time     35
# 3        4     Weekday     40
# 0        1   Full Time     50

# %%
df = pd.read_csv("../data/members_欠損値あり.csv")

# %%
df
# Out:
#       ID First Name  Last Name                         Email          Phone  \
# 0    100      Carol       Shaw                cshaw0@mlb.com  (206)804-8771
# 1    101  Elizabeth       Carr             ecarr1@oracle.com  (512)187-2507
# 2    102     Ernest      Ramos           eramos2@plala.or.jp  (816)540-4257
# 3    103       Jane     Carter          jcarter3@harvard.edu  (214)839-0542
# 4    104     Martha     Cooper               mcooper4@go.com  (727)235-5696
# ..   ...        ...        ...                           ...            ...
# 295  395      Diana      Hicks        dhicks87@bloglovin.com  (513)289-6421
# 296  396     Thomas    Griffin        tgriffin88@smugmug.com  (801)631-7393
# 297  397   Jonathan     Turner             jturner89@fc2.com  (310)968-4752
# 298  398     Jeremy   Robinson           jrobinson8a@gnu.org  (616)146-1693
# 299  399      David  Robertson  drobertson8b@istockphoto.com  (404)982-4393
#
#     Customer Type  Member Type
# ...

# %%
df.isnull()
# Out:
#         ID  First Name  Last Name  Email  Phone  Customer Type  Member Type
# 0    False       False      False  False  False          False        False
# 1    False       False      False  False  False          False        False
# 2    False       False      False  False  False          False        False
# 3    False       False      False  False  False          False        False
# 4    False       False      False  False  False          False        False
# ..     ...         ...        ...    ...    ...            ...          ...
# 295  False       False      False  False  False          False         True
# 296  False       False      False  False  False          False         True
# 297  False       False      False  False  False          False        False
# 298  False       False      False  False  False          False        False
# 299  False       False      False  False  False          False        False
#
# [300 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# ID                0
# First Name        0
# Last Name         0
# Email             0
# Phone             0
# Customer Type     4
# Member Type      10
# dtype: int64

# %%
df.sort_values("Member Type")
# Out:
#       ID First Name Last Name                       Email          Phone  \
# 0    100      Carol      Shaw              cshaw0@mlb.com  (206)804-8771
# 153  253     Teresa      Reed      treed49@prnewswire.com  (619)152-4245
# 154  254    Anthony      King              aking4a@wp.com  (281)318-2460
# 155  255       Tina    Kelley         tkelley4b@slate.com  (214)711-7757
# 156  256     Ashley   Vasquez  avasquez4c@dailymail.co.uk  (904)224-2121
# ..   ...        ...       ...                         ...            ...
# 292  392      Brian  Sullivan    bsullivan84@multiply.com  (202)804-6133
# 293  393      Aaron    Taylor           ataylor85@pbs.org  (210)195-9947
# 294  394    Frances     Jones          fjones86@wired.com  (361)941-0866
# 295  395      Diana     Hicks      dhicks87@bloglovin.com  (513)289-6421
# 296  396     Thomas   Griffin      tgriffin88@smugmug.com  (801)631-7393
#
#     Customer Type  Member Type
# 0      Individual          1.0
# ...

# %%
df.sort_values("Member Type", na_position="first")
# Out:
#       ID First Name Last Name                      Email          Phone  \
# 287  387    Timothy    Powell        tpowell7z@ocn.ne.jp  (239)709-4562
# 288  388     Albert     Baker   abaker80@dagondesign.com  (202)605-5298
# 289  389      Jerry    Bailey         jbailey81@usgs.gov  (507)746-0956
# 290  390    Heather    Murphy        hmurphy82@wiley.com  (847)103-7136
# 291  391   Patricia     Perez            pperez83@hp.com  (814)169-5409
# ..   ...        ...       ...                        ...            ...
# 221  321     Denise     Myers          dmyers65@ucoz.com  (202)646-6358
# 273  373    Michael     Burke        mburke7l@spiegel.de  (765)699-6462
# 218  318     Johnny    Butler     jbutler62@yolasite.com  (786)743-1707
# 220  320       Alan    Lawson  alawson64@livejournal.com  (816)804-1726
# 51   151       Earl  Richards      erichards1f@google.nl  (281)133-3455
#
#     Customer Type  Member Type
# 287      Business          NaN
# 288    Individual          NaN
# ...
