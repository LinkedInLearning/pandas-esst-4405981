# %%
import pandas as pd

# %%
df = pd.read_csv("../data/members_欠損値あり.csv")

# %%
df.isnull().sum()
# Out:
# ID                0
# First Name        0
# Last Name         0
# Email             0
# Phone             0
# Customer Type     4
# Member Type      10
# dtype: int64

# %%
df.isnull().any()
# Out:
# ID               False
# First Name       False
# Last Name        False
# Email            False
# Phone            False
# Customer Type     True
# Member Type       True
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 295     True
# 296     True
# 297    False
# 298    False
# 299    False
# Length: 300, dtype: bool

# %%
df[df["Customer Type"].isnull()]
# Out:
#      ID First Name  Last Name                     Email          Phone  \
# 74  174      Janet     Murphy         jmurphy22@php.net  (484)491-6418
# 75  175    Richard  Henderson       rhenderson23@360.cn  (703)668-7022
# 76  176    Antonio      Meyer      ameyer24@weather.com  (626)579-5161
# 77  177      Wayne  Robertson  wrobertson25@walmart.com  (202)264-0678
#
#    Customer Type  Member Type
# 74           NaN          1.0
# 75           NaN          1.0
# 76           NaN          1.0
# 77           NaN          1.0

# %%
df[df["Member Type"].isnull()]
# Out:
#       ID First Name Last Name                     Email          Phone  \
# 287  387    Timothy    Powell       tpowell7z@ocn.ne.jp  (239)709-4562
# 288  388     Albert     Baker  abaker80@dagondesign.com  (202)605-5298
# 289  389      Jerry    Bailey        jbailey81@usgs.gov  (507)746-0956
# 290  390    Heather    Murphy       hmurphy82@wiley.com  (847)103-7136
# 291  391   Patricia     Perez           pperez83@hp.com  (814)169-5409
# 292  392      Brian  Sullivan  bsullivan84@multiply.com  (202)804-6133
# 293  393      Aaron    Taylor         ataylor85@pbs.org  (210)195-9947
# 294  394    Frances     Jones        fjones86@wired.com  (361)941-0866
# 295  395      Diana     Hicks    dhicks87@bloglovin.com  (513)289-6421
# 296  396     Thomas   Griffin    tgriffin88@smugmug.com  (801)631-7393
#
#     Customer Type  Member Type
# 287      Business          NaN
# 288    Individual          NaN
# 289    Individual          NaN
# 290    Individual          NaN
# ...

# %%
df1 = df.fillna({"Customer Type" : "Individual"})

# %%
df1[df["ID"].isin([174,175,176,177])]
# Out:
#      ID First Name  Last Name                     Email          Phone  \
# 74  174      Janet     Murphy         jmurphy22@php.net  (484)491-6418
# 75  175    Richard  Henderson       rhenderson23@360.cn  (703)668-7022
# 76  176    Antonio      Meyer      ameyer24@weather.com  (626)579-5161
# 77  177      Wayne  Robertson  wrobertson25@walmart.com  (202)264-0678
#
#    Customer Type  Member Type
# 74    Individual          1.0
# 75    Individual          1.0
# 76    Individual          1.0
# 77    Individual          1.0

# %%
df1["Member Type"].fillna(df1["Member Type"].mode().iloc[0], inplace=True)

# %%
df1.tail()
# Out:
#       ID First Name  Last Name                         Email          Phone  \
# 295  395      Diana      Hicks        dhicks87@bloglovin.com  (513)289-6421
# 296  396     Thomas    Griffin        tgriffin88@smugmug.com  (801)631-7393
# 297  397   Jonathan     Turner             jturner89@fc2.com  (310)968-4752
# 298  398     Jeremy   Robinson           jrobinson8a@gnu.org  (616)146-1693
# 299  399      David  Robertson  drobertson8b@istockphoto.com  (404)982-4393
#
#     Customer Type  Member Type
# 295    Individual          1.0
# 296      Business          1.0
# 297    Individual          1.0
# 298    Individual          1.0
# 299    Individual          1.0
