# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "A列":[0,2,np.nan,4],
    "B列":[1,3,5,7],
    "C列":[2,np.nan,6,8],    
    "D列":[3,5,np.nan,9],
    "E列":[np.nan,6,8,10]    
})

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.isnull()
# Out:
#       A列     B列     C列     D列     E列
# 0  False  False  False  False   True
# 1  False  False   True  False  False
# 2   True  False  False   True  False
# 3  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# A列    1
# B列    0
# C列    1
# D列    1
# E列    1
# dtype: int64

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.dropna()
# Out:
#     A列  B列   C列   D列    E列
# 3  4.0   7  8.0  9.0  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.dropna(axis=0)
# Out:
#     A列  B列   C列   D列    E列
# 3  4.0   7  8.0  9.0  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(0)
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   0.0
# 1  2.0   3  0.0  5.0   6.0
# 2  0.0   5  6.0  0.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna({"A列":0,"C列":4,"D列":7,"E列":4})
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   4.0
# 1  2.0   3  4.0  5.0   6.0
# 2  0.0   5  6.0  7.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(method="ffill")
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  2.0  5.0   6.0
# 2  2.0   5  6.0  5.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(method="bfill")
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   6.0
# 1  2.0   3  6.0  5.0   6.0
# 2  4.0   5  6.0  9.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df1 = df.fillna(0)

# %%
df1
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   0.0
# 1  2.0   3  0.0  5.0   6.0
# 2  0.0   5  6.0  0.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(0, inplace=True)

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   0.0
# 1  2.0   3  0.0  5.0   6.0
# 2  0.0   5  6.0  0.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df = pd.DataFrame({
    "A列":[0,2,np.nan,4],
    "B列":[1,3,5,7],
    "C列":[2,np.nan,6,8],    
    "D列":[3,5,np.nan,9],
    "E列":[np.nan,6,8,10]    
})

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(df.mean())
# Out:
#     A列  B列        C列        D列    E列
# 0  0.0   1  2.000000  3.000000   8.0
# 1  2.0   3  5.333333  5.000000   6.0
# 2  2.0   5  6.000000  5.666667   8.0
# 3  4.0   7  8.000000  9.000000  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(df.median())
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   8.0
# 1  2.0   3  6.0  5.0   6.0
# 2  2.0   5  6.0  5.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(df.min())
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   6.0
# 1  2.0   3  2.0  5.0   6.0
# 2  0.0   5  6.0  3.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(df.max())
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0  10.0
# 1  2.0   3  8.0  5.0   6.0
# 2  4.0   5  6.0  9.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.fillna(df.mode().iloc[0])
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   6.0
# 1  2.0   3  2.0  5.0   6.0
# 2  0.0   5  6.0  3.0   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
df.mode().iloc[0]
# Out:
# A列    0.0
# B列    1.0
# C列    2.0
# D列    3.0
# E列    6.0
# Name: 0, dtype: float64

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
ser = df["A列"].fillna(df["B列"].mean())

# %%
df
# Out:
#     A列  B列   C列   D列    E列
# 0  0.0   1  2.0  3.0   NaN
# 1  2.0   3  NaN  5.0   6.0
# 2  NaN   5  6.0  NaN   8.0
# 3  4.0   7  8.0  9.0  10.0

# %%
ser
# Out:
# 0    0.0
# 1    2.0
# 2    4.0
# 3    4.0
# Name: A列, dtype: float64
